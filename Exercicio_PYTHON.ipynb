# %% [markdown]
# Importar bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# MANIPULAÇÃO DE DADOS
import pandas as pd
# OPERAÇÕES NUMÉRICAS E VETORIAIS
import numpy as np
# VISUALIZAÇÕES BASICAS E AVANÇADAS
import matplotlib.pyplot as plt
# GRAFICOS ESTATISTICOS COM ESTILO
import seaborn as sns

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0fc5630e-6fbf-42a4-9366-ec75562ce364" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fc5630e-6fbf-42a4-9366-ec75562ce364">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Re-importing the data to ensure 'df' is defined
df = pd.read_csv('dados_venda_empresa1.csv (2) (1).csv')

# %%
import pandas as pd
#IMPORTANDO OS DADOS LENDO O DATA FRAME
df = pd.read_csv('dados_venda_empresa1.csv (1).csv')

# %%
#ver as primeiras linhas do data frame
print(df.head)
# Out:
# <bound method NDFrame.head of      data_venda          nome_cliente estado    nome_produto    categoria  \
# 0    2025-05-11   Dra, Mariana da Paz     BA           Leite    Alimentos
# 1    2025-03-14       Marcela Rezende     BA          Feijão    Alimentos
# 2    2025-04-18    Srta, Brenda Cunha     BA   Quebra-Cabeça   Brinquedos
# 3    2025-02-09  Maria Clara Caldeira     BA  Fone de Ouvido  Eletrônicos
# 4    2025-04-10   João Felipe Cardoso     BA        Carrinho   Brinquedos
# ..          ...                   ...    ...             ...          ...
# 195  2025-04-05           Pedro Sales     SP            Café    Alimentos
# 196  2024-12-17        Catarina Costa     SP             Pão    Alimentos
# 197  2025-02-15      Sr, Igor da Mota     SP         Jaqueta    Vestuário
# 198  2025-03-28        Amanda Costela     SP           Leite    Alimentos
# 199  2025-02-24  Maria Vitória Aragão     SP           Arroz    Alimentos
#
# ...

# %% [markdown]
# CONHECER OS NOSSOS DADOS

# %%
print(f"\nSeu dataset tem {df.shape[0] } linhas e {df.shape[1]} colunas")
# Out:
# Seu dataset tem 200 linhas e 14 colunas

# %%
#nomes das colunas
print(df.columns)
# Out:
# Index(['data_venda', 'nome_cliente', 'estado', 'nome_produto', 'categoria',
#        'quantidade', 'preco_unitario', 'total_venda', 'quantidade_estoque',
#        'localizacao_estoque', 'ano', 'mes', 'dia', 'dia da semana'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['data_venda', 'nome_cliente', 'estado', 'nome_produto', 'categoria', 'quantidade', 'preco_unitario', 'total_venda', 'quantidade_estoque', 'localizacao_estoque', 'ano', 'mes', 'dia', 'dia da semana']

# %%
#verificar se os dados estão corretos
dados_faltantes = df.isnull().sum()
print(dados_faltantes)
# Out:
# data_venda             0
# nome_cliente           0
# estado                 0
# nome_produto           0
# categoria              0
# quantidade             0
# preco_unitario         0
# total_venda            0
# quantidade_estoque     0
# localizacao_estoque    0
# ano                    0
# mes                    0
# dia                    0
# dia da semana          0
# dtype: int64

# %%
#resumo esatistico simples
print(df.describe())
# Out:
#        quantidade  quantidade_estoque          ano         mes         dia  \
# count  200.000000          200.000000   200.000000  200.000000  200.000000
# mean     5.805000          162.870000  2024.850000    4.450000   16.405000
# std      2.927426           81.097392     0.357967    3.488315    8.609973
# min      1.000000           11.000000  2024.000000    1.000000    1.000000
# 25%      3.000000           97.750000  2025.000000    2.000000   10.000000
# 50%      6.000000          169.000000  2025.000000    4.000000   17.000000
# 75%      8.000000          233.250000  2025.000000    5.000000   24.000000
# max     10.000000          298.000000  2025.000000   12.000000   31.000000
#
#        dia da semana
# count      200.00000
# mean         4.05000
# std          2.18894
# min          1.00000
# 25%          2.00000
# 50%          4.00000
# 75%          6.00000
# max          7.00000

# %%
#valores zerados colunas numericas
df[['quantidade','preco_unitario','total_venda']].eq(0).sum()
# Out:
# quantidade        0
# preco_unitario    0
# total_venda       0
# dtype: int64

# %% [markdown]
# OPERAÇÕES BÁSICAS NO PYTHON

# %%
#somar uma coluna
print(df['total_venda'].sum())
# Out:
# 1682529.3800000001

# %%
#multiplicando colunas
df['total_venda'] = df['quantidade'] * df['preco_unitario']
print(df['total_venda'])
# Out:
# 0      1.610,731.610,731.610,731.610,731.610,731.610,...
# 1      2.406,942.406,942.406,942.406,942.406,942.406,...
# 2                                               2.192,52
# 3                                       2.008,932.008,93
# 4       624,63624,63624,63624,63624,63624,63624,63624,63
#                              ...
# 195             2.426,592.426,592.426,592.426,592.426,59
# 196                       158,02158,02158,02158,02158,02
# 197    1.733,911.733,911.733,911.733,911.733,911.733,...
# 198     1.224,691.224,691.224,691.224,691.224,691.224,69
# 199    1.491,661.491,661.491,661.491,661.491,661.491,...
# Name: total_venda, Length: 200, dtype: object

# %%
#média da coluna quantidade
print(df['quantidade'].mean())
# Out:
# 5.805

# %% [markdown]
# FILTROS

# %%
#Filtrar itens da categoria eletrônicos
print(df[df['categoria'] == 'Eletrônicos'])
# Out:
#      data_venda              nome_cliente estado    nome_produto    categoria  \
# 3    2025-02-09      Maria Clara Caldeira     BA  Fone de Ouvido  Eletrônicos
# 5    2025-04-04             Alana Peixoto     BA  Fone de Ouvido  Eletrônicos
# 8    2024-12-21                Davi Silva     BA          Tablet  Eletrônicos
# 15   2025-04-10          Vicente Teixeira     BA  Fone de Ouvido  Eletrônicos
# 19   2025-01-13             Daniela Rocha     BA        Notebook  Eletrônicos
# 20   2025-03-16           Nathan Teixeira     BA          Tablet  Eletrônicos
# 22   2024-12-19      Sr, Benício da Cunha     BA         Monitor  Eletrônicos
# 25   2025-01-22               Ian Pereira     BA  Fone de Ouvido  Eletrônicos
# 35   2024-12-27            Thales Pereira     BA  Fone de Ouvido  Eletrônicos
# 43   2025-05-27        Davi Lucca Cardoso     MG      Smartphone  Eletrônicos
# 44   2024-12-22         Emanuelly Correia     MG      Smartphone  Eletrônicos
# ...

# %%
#Filtros compostos e combinados
print(df[(df['categoria'] == 'Eletrônicos') & (df['quantidade'] >3)])
# Out:
#      data_venda              nome_cliente estado    nome_produto    categoria  \
# 5    2025-04-04             Alana Peixoto     BA  Fone de Ouvido  Eletrônicos
# 8    2024-12-21                Davi Silva     BA          Tablet  Eletrônicos
# 15   2025-04-10          Vicente Teixeira     BA  Fone de Ouvido  Eletrônicos
# 20   2025-03-16           Nathan Teixeira     BA          Tablet  Eletrônicos
# 22   2024-12-19      Sr, Benício da Cunha     BA         Monitor  Eletrônicos
# 25   2025-01-22               Ian Pereira     BA  Fone de Ouvido  Eletrônicos
# 35   2024-12-27            Thales Pereira     BA  Fone de Ouvido  Eletrônicos
# 49   2025-01-03     Luiz Henrique Pereira     MG      Smartphone  Eletrônicos
# 59   2025-04-04      Dra, Catarina Castro     PE          Tablet  Eletrônicos
# 61   2025-03-07               Clara Viana     PE         Monitor  Eletrônicos
# 67   2025-05-28      Luiz Gustavo Freitas     PE         Monitor  Eletrônicos
# ...

# %% [markdown]
# Agrupamentos

# %%
#média de quantidade vendida por categoria
print(df.groupby('categoria')['quantidade'].mean())
# Out:
# categoria
# Alimentos      5.682927
# Brinquedos     5.590909
# Eletrônicos    6.694444
# Móveis         5.361111
# Vestuário      5.767442
# Name: quantidade, dtype: float64

# %%
#soma de quantidade vendad por categoria
print(df.groupby('categoria')['quantidade'].sum())
# Out:
# categoria
# Alimentos      233
# Brinquedos     246
# Eletrônicos    241
# Móveis         193
# Vestuário      248
# Name: quantidade, dtype: int64

# %%
#multiplas estátisticas por categoria
print(df.groupby('categoria')['quantidade'].agg(['mean','sum','count','max','min']))
# Out:
#                  mean  sum  count  max  min
# categoria
# Alimentos    5.682927  233     41   10    1
# Brinquedos   5.590909  246     44   10    1
# Eletrônicos  6.694444  241     36   10    1
# Móveis       5.361111  193     36   10    1
# Vestuário    5.767442  248     43   10    1

# %% [markdown]
# Gráficos

# %%
# 1. Corrigir e converter a coluna preco_unitario
df['preco_unitario'] = (
    df['preco_unitario']
    .astype(str)                 # garante que é string
    .str.replace('.', '', regex=False)   # remove ponto dos milhares
    .str.replace(',', '.', regex=False)  # troca vírgula decimal por ponto
)

# 2. Converter para float
df['preco_unitario'] = pd.to_numeric(df['preco_unitario'], errors='coerce')

# 3. Converter quantidade, se necessário
df['quantidade'] = pd.to_numeric(df['quantidade'], errors='coerce')

# 4. Multiplicar
df['total_venda'] = df['quantidade'] * df['preco_unitario']

# 5. Verificar tipo final
print(df['total_venda'].dtype)  # deve retornar float64
# Out:
# float64

# %%
#grafico simples de barras
df['categoria'].value_counts().plot(kind='bar')
plt.show()

# %%
#histrograma de distribuição dos valores de venda 'total_venda"
df['total_venda'].hist(bins=20)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['total_venda'].hist(bins=20)
plt.title('Distribuição das Vendas')
plt.xlabel('Valor das Vendas')
plt.ylabel('Frequência')
plt.show()

# %%
#grafico de barras horizontais com o total_venda
df.groupby('categoria')['total_venda'].sum().sort_values(ascending=True).plot(kind='barh')
plt.show()

# %%
df.groupby('categoria')['total_venda'].sum().sort_values(ascending=True).plot(kind='pie')
plt.show()

# %%
#grafico de area horizontais com o total_venda
df.groupby('categoria')['total_venda'].sum().sort_values(ascending=True).plot(kind='area')
plt.show()

# %% [markdown]
# Criar uma coluna nova cliente VIP OU NAO VIP

# %%
#criar uma nova coluna STATUS do CLIENTE
df.loc[df['total_venda'] > 1000, 'status_cliente'] = 'VIP'
df.loc[df['total_venda'] <= 1000, 'status_cliente'] = 'NAO VIP'

# %%
#vendo o head do data set
print(df.head())
# Out:
#    data_venda          nome_cliente estado    nome_produto    categoria  \
# 0  2025-05-11   Dra, Mariana da Paz     BA           Leite    Alimentos
# 1  2025-03-14       Marcela Rezende     BA          Feijão    Alimentos
# 2  2025-04-18    Srta, Brenda Cunha     BA   Quebra-Cabeça   Brinquedos
# 3  2025-02-09  Maria Clara Caldeira     BA  Fone de Ouvido  Eletrônicos
# 4  2025-04-10   João Felipe Cardoso     BA        Carrinho   Brinquedos
#
#    quantidade  preco_unitario  total_venda  quantidade_estoque  \
# 0           9         1610.73     14496.57                 116
# 1           7         2406.94     16848.58                 131
# 2           1         2192.52      2192.52                 224
# 3           2         2008.93      4017.86                 201
# 4           8          624.63      4997.04                 170
#
#   localizacao_estoque   ano  mes  dia  dia da semana status_cliente
# 0            C3-A2-B2  2025    5   11              1            VIP
# ...

# %% [markdown]
# Trabalhando com datas

# %%
#garantir que as informacoes de data estão no formato datetime
df['data_venda'] = pd.to_datetime(df['data_venda'])

# %%
#extrair informacao de data
df['ano_venda'] = df['data_venda'].dt.year
df['mes_venda'] = df['data_venda'].dt.month
df['dia_venda'] = df['data_venda'].dt.day
df['dia da semana'] = df['data_venda'].dt.dayofweek

# %% [markdown]
# Análise de oportunidades

# %%
#qual o total de vendas?
print(df['total_venda'].sum())
# Out:
# 1682529.3800000001

# %%
#qual a media de vendas?
print(df['total_venda'].mean())
# Out:
# 8412.6469

# %%
#qual categoria vende mais?
print(df.groupby('categoria')['total_venda'].sum())
# Out:
# categoria
# Alimentos      378777.27
# Brinquedos     331006.07
# Eletrônicos    322217.60
# Móveis         286853.41
# Vestuário      363675.03
# Name: total_venda, dtype: float64

# %%
#maior venda individual?
print(df['total_venda'].max())
# Out:
# 26662.590000000004

# %%
#dia da semana com a maior venda?
print(df.groupby('dia da semana')['total_venda'].sum())
# Out:
# dia da semana
# 0    204156.36
# 1    193726.40
# 2     77299.24
# 3    237890.78
# 4    372577.58
# 5    355882.57
# 6    240996.45
# Name: total_venda, dtype: float64

# %%
#qual mes vendeu menos?
print(df.groupby('mes_venda')['total_venda'].sum())
# Out:
# mes_venda
# 1     253222.88
# 2     315849.32
# 3     287268.72
# 4     298945.33
# 5     276175.41
# 6      60757.73
# 12    190309.99
# Name: total_venda, dtype: float64

# %% [markdown]
# Análise final

# %%
#grafico de vendas totais por mes
df.groupby('mes_venda')['total_venda'].sum().plot(kind='bar')
plt.show()

# %%
#grafico de pizza do percentual de vendas por categoria
df.groupby('categoria')['total_venda'].sum().plot(kind='pie')
plt.show()

# %%
#grafico de vendas medias por dia da semana
df.groupby('dia da semana')['total_venda'].mean().plot(kind='bar')
plt.show()

# %%
#grafico de dispersao do dia da semana com o total de venda
plt.scatter(df['dia da semana'], df['total_venda'])
plt.show()

# %%
#boxplot da distribuição de vendas por dia
df.boxplot(column='total_venda', by='dia da semana')
plt.show()

# %%
#boxplot do total de venda por categoria
df.boxplot(column='total_venda', by='categoria')
plt.show()

# %%
#boxplot do total de venda por mes
df.boxplot(column='total_venda', by='mes_venda')
plt.show()

# %%
#comparando o valor medio de vendas entre vip e nao vip
df.groupby('status_cliente')['total_venda'].mean().plot(kind='bar')
plt.show()

# %%
#comparando o valor medio de vendas entre vip e nao vip
print(df.groupby('status_cliente')['total_venda'].mean())
# Out:
# status_cliente
# NAO VIP     534.383333
# VIP        9191.815824
# Name: total_venda, dtype: float64

# %%
#comparando o valor total vendido por status
print(df.groupby('status_cliente')['total_venda'].sum())
# Out:
# status_cliente
# NAO VIP       9618.90
# VIP        1672910.48
# Name: total_venda, dtype: float64

# %%
#comparando as compras dos vips e nao vips por categoria
print(df.groupby(['status_cliente', 'categoria'])['total_venda'].sum())
# Out:
# status_cliente  categoria
# NAO VIP         Alimentos        1225.15
#                 Brinquedos       2359.33
#                 Eletrônicos      2610.03
#                 Móveis           1533.56
#                 Vestuário        1890.83
# VIP             Alimentos      377552.12
#                 Brinquedos     328646.74
#                 Eletrônicos    319607.57
#                 Móveis         285319.85
#                 Vestuário      361784.20
# Name: total_venda, dtype: float64

# %% [markdown]
# CONCLUSÃO DA ESTRATÉGIA

# %%
#gerar um grafico de pizza comparando o total de venda de vips e nao vips
df.groupby('status_cliente')['total_venda'].sum().plot(kind='pie')
plt.show()

# %%
#gerar um grafico de barras comparando as compras dos vips e nao vips por categoria
print(df.groupby(['status_cliente', 'categoria'])['total_venda'].sum().unstack().plot(kind='bar'))
plt.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)
